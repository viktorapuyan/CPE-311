# %% [markdown]
# #Data Analysis

# %%
import numpy as np
import pandas as pd

# %%
filepath = '/content/val_stats.csv'
val_stats = pd.read_csv(filepath)
val_stats
# Out:
# <ipython-input-6-4732445712b9>:2: DtypeWarning: Columns (0,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   val_stats = pd.read_csv(filepath)
#       region            name     tag      rating  damage_round headshots  \
# 0        NaN        ShimmyXD    #NA1     Radiant         135.8       992
# 1        NaN       XSET Cryo  #cells     Radiant         170.3       879
# 2        NaN   PuRelittleone  #yoruW     Radiant         147.5       720
# 3        NaN            Boba   #0068     Radiant         178.2       856
# 4        NaN     i love mina  #kelly     Radiant         149.8       534
# ...      ...             ...     ...         ...           ...       ...
# 85673    LAT        Kazutora  #img0d     Radiant         138.2       342
# 85674    LAT  el lobo marino  #uthur     Radiant         182.9       650
# 85675    LAT          p9pzet   #666x     Radiant         158.8       613
# ...

# %%
#identify the column names of the dataset
column_names = list(val_stats.columns.values)
print("Column Names :", column_names)
# Out:
# Column Names : ['region', 'name', 'tag', 'rating', 'damage_round', 'headshots', 'headshot_percent', 'aces', 'clutches', 'flawless', 'first_bloods', 'kills', 'deaths', 'assists', 'kd_ratio', 'kills_round', 'most_kills', 'score_round', 'wins', 'win_percent', 'agent_1', 'agent_2', 'agent_3', 'gun1_name', 'gun1_head', 'gun1_body', 'gun1_legs', 'gun1_kills', 'gun2_name', 'gun2_head', 'gun2_body', 'gun2_legs', 'gun2_kills', 'gun3_name', 'gun3_head', 'gun3_body', 'gun3_legs', 'gun3_kills']

# %%
#identify the data types of the dataset
df = pd.DataFrame(val_stats)
results = df.dtypes
print(results)
# Out:
# region               object
# name                 object
# tag                  object
# rating               object
# damage_round        float64
# headshots            object
# headshot_percent    float64
# aces                  int64
# clutches              int64
# flawless              int64
# first_bloods         object
# kills                object
# deaths               object
# assists              object
# kd_ratio            float64
# kills_round         float64
# most_kills            int64
# score_round         float64
# wins                  int64
# win_percent         float64
# agent_1              object
# agent_2              object
# agent_3              object
# gun1_name            object
# gun1_head             int64
# gun1_body             int64
# gun1_legs             int64
# gun1_kills           object
# gun2_name            object
# gun2_head             int64
# gun2_body             int64
# gun2_legs             int64
# gun2_kills           object
# ...

# %%
text = "Total Number of Records: "
total_records = len(val_stats)
print(text + str(total_records))
# Out:
# Total Number of Records: 85678

# %%
#displaying the first 20 records of the dataset
val_stats.head(20)
# Out:
#    region           name     tag   rating  damage_round headshots  \
# 0     NaN       ShimmyXD    #NA1  Radiant         135.8       992
# 1     NaN      XSET Cryo  #cells  Radiant         170.3       879
# 2     NaN  PuRelittleone  #yoruW  Radiant         147.5       720
# 3     NaN           Boba   #0068  Radiant         178.2       856
# 4     NaN    i love mina  #kelly  Radiant         149.8       534
# 5     NaN          Decay   #GODK  Radiant         134.1     1,038
# 6     NaN          Osias   #1212  Radiant         163.4     1,472
# 7     NaN   Knights RIKU    #KRN  Radiant         153.3       510
# 8     NaN       RaijuACE   #3131  Radiant         153.7     1,181
# 9     NaN           dawn    #24k  Radiant         153.6       339
# 10    NaN    100T Derrek    #100  Radiant         144.2       795
# 11    NaN        acts017    #ttv  Radiant         137.8       868
# 12    NaN        sam wow  #linda  Radiant         142.2     1,226
# ...

# %%
#diaplaying the last 20 records of the dataset
val_stats.tail(20)
# Out:
#       region            name     tag      rating  damage_round headshots  \
# 85658    LAT        erenueve   #dvid     Radiant         168.3     1,110
# 85659    LAT         ERMAAAK   #1337     Radiant         142.7       980
# 85660    LAT           zacar   #6366     Radiant         148.4       585
# 85661    LAT            tehx   #deuS     Radiant         158.0       563
# 85662    LAT           Tegui    #Col     Radiant         158.9       970
# 85663    LAT             TDY   #1996     Radiant         146.2       997
# 85664    LAT           mgnus    #LAS     Radiant         151.2       798
# 85665    LAT            VnuS  #20100     Radiant         147.3       725
# 85666    LAT            DRIB    #uma     Radiant         152.4       681
# 85667    LAT        STG wait   #1337     Radiant         137.4     1,101
# 85668    LAT   GanTerw0w ç”˜    #CHL     Radiant         166.3     1,189
# 85669    LAT          Mesmer  #Rende     Radiant         149.1     1,249
# ...

# %%
#change the rating column to ranked rating
#before renaming
val_stats
# Out:
#       region            name     tag      rating  damage_round headshots  \
# 0        NaN        ShimmyXD    #NA1     Radiant         135.8       992
# 1        NaN       XSET Cryo  #cells     Radiant         170.3       879
# 2        NaN   PuRelittleone  #yoruW     Radiant         147.5       720
# 3        NaN            Boba   #0068     Radiant         178.2       856
# 4        NaN     i love mina  #kelly     Radiant         149.8       534
# ...      ...             ...     ...         ...           ...       ...
# 85673    LAT        Kazutora  #img0d     Radiant         138.2       342
# 85674    LAT  el lobo marino  #uthur     Radiant         182.9       650
# 85675    LAT          p9pzet   #666x     Radiant         158.8       613
# 85676    LAT  EZ4TGD EnSBuwu  #kmeve  Immortal 3         155.9       132
# 85677    LAT            Neon    #SSJ     Radiant         164.4     1,127
#
#        headshot_percent  aces  clutches  flawless  ... gun2_name gun2_head  \
# ...

# %%
#after renaming rating into Ranked rating
val_stats.rename(columns = {'rating' : 'Ranked Rating'}, inplace = True)
val_stats.head()
# Out:
#   region           name     tag Ranked Rating  damage_round headshots  \
# 0    NaN       ShimmyXD    #NA1       Radiant         135.8       992
# 1    NaN      XSET Cryo  #cells       Radiant         170.3       879
# 2    NaN  PuRelittleone  #yoruW       Radiant         147.5       720
# 3    NaN           Boba   #0068       Radiant         178.2       856
# 4    NaN    i love mina  #kelly       Radiant         149.8       534
#
#    headshot_percent  aces  clutches  flawless  ... gun2_name gun2_head  \
# 0              24.9     0       140        80  ...   Phantom        33
# 1              28.3     2       122        94  ...  Operator         8
# 2              24.0     3       117        59  ...   Phantom        36
# 3              37.3     3        83        49  ...   Sheriff        48
# 4              24.4     2        71        38  ...   Spectre        21
#
#   gun2_body gun2_legs  gun2_kills  gun3_name  gun3_head  gun3_body  gun3_legs  \
# ...

# %%
val_stats['Ranked Elo'] = np.where(val_stats['Ranked Rating'] == 'Radiant', 'High Immortal', 'Low immortal')
val_stats
# Out:
#       region            name     tag Ranked Rating  damage_round headshots  \
# 0        NaN        ShimmyXD    #NA1       Radiant         135.8       992
# 1        NaN       XSET Cryo  #cells       Radiant         170.3       879
# 2        NaN   PuRelittleone  #yoruW       Radiant         147.5       720
# 3        NaN            Boba   #0068       Radiant         178.2       856
# 4        NaN     i love mina  #kelly       Radiant         149.8       534
# ...      ...             ...     ...           ...           ...       ...
# 85673    LAT        Kazutora  #img0d       Radiant         138.2       342
# 85674    LAT  el lobo marino  #uthur       Radiant         182.9       650
# 85675    LAT          p9pzet   #666x       Radiant         158.8       613
# 85676    LAT  EZ4TGD EnSBuwu  #kmeve    Immortal 3         155.9       132
# 85677    LAT            Neon    #SSJ       Radiant         164.4     1,127
#
# ...

# %%
#Creating a new dataframe "high immortal" that gathers data of players ranked rating of high immortal three players from Immortal 3 to Radiant
val_stats = pd.DataFrame(val_stats)
high_immo_three = val_stats[val_stats['Ranked Rating'] == 'Radiant'].copy()

high_immo_three
# Out:
#       region            name     tag Ranked Rating  damage_round headshots  \
# 0        NaN        ShimmyXD    #NA1       Radiant         135.8       992
# 1        NaN       XSET Cryo  #cells       Radiant         170.3       879
# 2        NaN   PuRelittleone  #yoruW       Radiant         147.5       720
# 3        NaN            Boba   #0068       Radiant         178.2       856
# 4        NaN     i love mina  #kelly       Radiant         149.8       534
# ...      ...             ...     ...           ...           ...       ...
# 85672    LAT    BlackLÃ¸ttus    #LAS       Radiant         149.7       437
# 85673    LAT        Kazutora  #img0d       Radiant         138.2       342
# 85674    LAT  el lobo marino  #uthur       Radiant         182.9       650
# 85675    LAT          p9pzet   #666x       Radiant         158.8       613
# 85677    LAT            Neon    #SSJ       Radiant         164.4     1,127
#
# ...

# %%
#Creating a new dataframe "high immortal" that gathers data of players ranked rating of low immortal three players from Immortal 2 and below
val_stats = pd.DataFrame(val_stats)
low_immo_three = val_stats[val_stats['Ranked Rating'] == 'Immortal 2'].copy()

low_immo_three
# Out:
#       region            name     tag Ranked Rating  damage_round headshots  \
# 366      NaN            mish   #9779    Immortal 2         144.2       682
# 368      NaN         cawhnur  #blxty    Immortal 2         140.3       561
# 369      NaN         Escanor   #GMJA    Immortal 2         137.8       710
# 371      NaN           Byxes    #NA1    Immortal 2         151.6       190
# 372      NaN          MLDoom    #NA1    Immortal 2         142.4       538
# ...      ...             ...     ...           ...           ...       ...
# 84749    LAT      quickmarck    #LAS    Immortal 2         126.7       635
# 84750    LAT       LS REIVEN   #6499    Immortal 2         138.4       710
# 84784    LAT  atomiczzëª©í‘œ   #6969    Immortal 2         151.5       349
# 84797    LAT         Equinox   #2691    Immortal 2         137.8       604
# 84806    LAT          zhikoo    #LAS    Immortal 2         143.5       518
#
# ...

# %%
#descriptive statistivs of the dataset
val_stats.describe()
# Out:
#        damage_round  headshot_percent          aces      clutches  \
# count  85678.000000      85678.000000  85678.000000  85678.000000
# mean     142.815934         23.599013      1.058697     66.347254
# std       16.470485          5.187779      1.492623     53.117926
# min        0.000000          0.000000      0.000000      0.000000
# 25%      132.800000         20.000000      0.000000     27.000000
# 50%      142.000000         23.300000      1.000000     54.000000
# 75%      151.800000         26.800000      2.000000     92.000000
# max      340.600000         83.300000     24.000000    488.000000
#
#            flawless      kd_ratio   kills_round    most_kills   score_round  \
# count  85678.000000  85678.000000  85678.000000  85678.000000  85678.000000
# mean      39.112258      1.053942      0.758051     28.164371    218.225829
# std       31.073547      0.157280      0.098120      5.215834     26.331791
# ...
